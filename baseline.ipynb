# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("data.csv",  sep="\t")
data.col
# data.drop(["Unnamed: 0"	"myID"	"Source"	Target	"])
# Out:
#        Unnamed: 0        myID  \
# 0               2  ID00000002
# 1               7  ID00000007
# 2               8  ID00000008
# 3              13  ID00000013
# 4              14  ID00000014
# ...           ...         ...
# 26399       50251  ID00050251
# 26400       50253  ID00050253
# 26401       50254  ID00050254
# 26402       50256  ID00050256
# 26403       50257  ID00050257
#
#                                                   Source  \
# 0      C C ( C ) ( C ) N N C ( C ) ( C # N ) C 1 C C ...
# 1      C C ( C ) N . O = C 1 C C C ( c 2 c c c ( O C ...
# 2      C O . O = C ( O ) C C C ( = O ) c 1 c c c c c ...
# 3      C C ( = O ) c 1 c c c 2 c ( c 1 ) C ( C ) ( C ...
# 4      C S c 1 c c c ( N = C = O ) c c 1 . O C c 1 c ...
# ...                                                  ...
# 26399  N # C c 1 c ( - c 2 c c c ( O ) c c 2 ) n n 2 ...
# 26400  N C ( = O ) c 1 c ( - c 2 c c c ( O c 3 c c c ...
# 26401  C C ( C ) ( C ) O C ( = O ) N C C N 1 C C N ( ...
# ...
