# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### DAY 3 TASKS:
# 1) разделить полученный датасет на train и test (размер test пусть будет 0.2)
# 2) обучить модель xgboost (параметры дефолтные) на train, вывести метрики R2, RMSE
# 3) сделать проверку на test, вывести R2, RMSE
# 4) построить точечный график зависимости истинных значений от предсказанных (точечки тест и трэйн покрасить разными цветами)

# %%
data = pd.read_csv("data_new.csv")
data
# Out:
#        Unnamed: 0  Yield  reac1_0  reac1_1  reac1_2  reac1_3  reac1_4  \
# 0               0   95.0        0        0        0        0        0
# 1               1  100.0        0        1        0        0        0
# 2               2   98.0        0        0        0        0        0
# 3               3   78.6        1        0        0        1        0
# 4               4   95.0        0        0        1        0        0
# ...           ...    ...      ...      ...      ...      ...      ...
# 24626       24626   62.0        1        0        0        0        0
# 24627       24627   83.0        1        0        0        0        0
# 24628       24628   58.0        0        1        1        0        0
# 24629       24629   57.6        1        1        0        0        0
# 24630       24630   74.4        0        0        0        0        0
#
#        reac1_5  reac1_6  reac1_7  ...  preact_90  preact_91  preact_92  \
# ...

# %% [markdown]
# ML PART

# %%
data
# Out:
#        Unnamed: 0  Yield  reac1_0  reac1_1  reac1_2  reac1_3  reac1_4  \
# 0               0   95.0        0        0        0        0        0
# 1               1  100.0        0        1        0        0        0
# 2               2   98.0        0        0        0        0        0
# 3               3   78.6        1        0        0        1        0
# 4               4   95.0        0        0        1        0        0
# ...           ...    ...      ...      ...      ...      ...      ...
# 24626       24626   62.0        1        0        0        0        0
# 24627       24627   83.0        1        0        0        0        0
# 24628       24628   58.0        0        1        1        0        0
# 24629       24629   57.6        1        1        0        0        0
# 24630       24630   74.4        0        0        0        0        0
#
#        reac1_5  reac1_6  reac1_7  ...  preact_90  preact_91  preact_92  \
# ...

# %%
from sklearn.model_selection import train_test_split

features = data.columns[2:]
target = "Yield"

xtrain, xtest, ytrain, ytest = train_test_split(data[features], data[target], test_size=0.20, random_state=42)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

import xgboost as xg


xgb_r = xg.XGBRegressor(seed = 42)
xgb_r.fit(xtrain, ytrain)
pred = xgb_r.predict(xtest)

RMSE = mean_squared_error(ytest, pred, squared=False)
R2 = r2_score(ytest, pred)  

print("RMSE: ",RMSE)
print("R2: ",R2)
# Out:
# RMSE:  24.71718871035254
# R2:  0.05795146497685433

# %%
import matplotlib.pyplot as plt


plt.scatter(range(len(ytest)), ytest)
plt.scatter(range(len(pred)), pred)
plt.xlabel("Index")
plt.ylabel("Yield")
plt.legend(['true Yield', 'pred Yield'])
plt.show()

# %%
plt.scatter(ytest,pred)
plt.title("Dependece")
plt.xlabel("Real Yield")
plt.ylabel("Predcited Yield")
plt.show()
